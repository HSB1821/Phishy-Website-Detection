# %% [markdown]
# # Getting Dataset File

# %%
# Loading Packages

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading CSV Dataset file with id column as index
data= pd.read_csv("Phishy_website_dataset.csv", index_col = [0])

# %%
# Making DataFrame
df= pd.DataFrame(data)

# %%
# Head function shows first 5 Rows of DataFrame
df.head()
# Out:
#     having_IP_Address  URL_Length  Shortining_Service  having_At_Symbol  \
# id
# 1                  -1           1                   1                 1
# 2                   1           1                   1                 1
# 3                   1           0                   1                 1
# 4                   1           0                   1                 1
# 5                   1           0                  -1                 1
#
#     double_slash_redirecting  Prefix_Suffix  having_Sub_Domain  \
# id
# 1                         -1             -1                 -1
# 2                          1             -1                  0
# 3                          1             -1                 -1
# 4                          1             -1                 -1
# 5                          1             -1                  1
#
#     SSLfinal_State  Domain_registeration_length  Favicon  ...  popUpWidnow  \
# id                                                        ...
# ...

# %% [markdown]
# # Data Analysis and Wrangling

# %%
x= df.iloc[:,:-1] # x stores all rows of DataFrame from first column to second last column
y= df.iloc[:,-1]  # y stores all rows of last column of DataFrame

# %%
# To check whether data in the DataFrame contains any Null value / Empty cell

df.isnull().sum()
# Out:
# having_IP_Address              0
# URL_Length                     0
# Shortining_Service             0
# having_At_Symbol               0
# double_slash_redirecting       0
# Prefix_Suffix                  0
# having_Sub_Domain              0
# SSLfinal_State                 0
# Domain_registeration_length    0
# Favicon                        0
# port                           0
# HTTPS_token                    0
# Request_URL                    0
# URL_of_Anchor                  0
# Links_in_tags                  0
# SFH                            0
# Submitting_to_email            0
# Abnormal_URL                   0
# Redirect                       0
# on_mouseover                   0
# RightClick                     0
# popUpWidnow                    0
# Iframe                         0
# age_of_domain                  0
# DNSRecord                      0
# web_traffic                    0
# Page_Rank                      0
# Google_Index                   0
# ...

# %% [markdown]
# ## Basic Exploratory Data Analysis (EDA)

# %%
# To Graphically Represent output of Dataset
# Here '1' Represents Legitimate Website and '-1' Represents Phishy Website
sns.countplot(x='Result',data= data)
plt.show()

# %% [markdown]
# ### Various Effects of Features in DataFrame

# %%
# Make Histogram Representation of Effects of Various Features in DataFrame
data.hist(edgecolor='black', linewidth=1.2)
fig=plt.gcf()
fig.set_size_inches(20,15)
plt.show()

# %% [markdown]
# ### Violen Plot using Seaborn

# %%
plt.figure(figsize=(15,10))
plt.subplot(4,2,1)
sns.violinplot(x='Result',y='having_IP_Address',data=data)
plt.subplot(4,2,2)
sns.violinplot(x='Result',y='URL_Length',data=data)
plt.subplot(4,2,3)
sns.violinplot(x='Result',y='Shortining_Service',data=data)
plt.subplot(4,2,4)
sns.violinplot(x='Result',y='having_At_Symbol',data=data)
plt.subplot(4,2,5)
sns.violinplot(x='Result',y='double_slash_redirecting',data=data)
plt.subplot(4,2,6)
sns.violinplot(x='Result',y='Prefix_Suffix',data=data)
plt.subplot(4,2,7)
sns.violinplot(x='Result',y='having_Sub_Domain',data=data)
plt.subplot(4,2,8)
sns.violinplot(x='Result',y='SSLfinal_State',data=data)
plt.subplot(4,3,1)
sns.violinplot(x='Result',y='Domain_registeration_length',data=data)
plt.subplot(4,3,2)
sns.violinplot(x='Result',y='Favicon',data=data)
plt.subplot(4,3,3)
sns.violinplot(x='Result',y='port',data=data)
plt.subplot(4,3,4)
sns.violinplot(x='Result',y='HTTPS_token',data=data)
plt.subplot(4,3,5)
sns.violinplot(x='Result',y='Request_URL',data=data)
plt.subplot(4,3,6)
sns.violinplot(x='Result',y='URL_of_Anchor',data=data)
plt.subplot(4,3,7)
sns.violinplot(x='Result',y='Links_in_tags',data=data)
plt.subplot(4,3,8)
sns.violinplot(x='Result',y='SFH',data=data)
plt.subplot(4,4,1)
sns.violinplot(x='Result',y='Submitting_to_email',data=data)
plt.subplot(4,4,2)
sns.violinplot(x='Result',y='Abnormal_URL',data=data)
plt.subplot(4,4,3)
sns.violinplot(x='Result',y='Redirect',data=data)
plt.subplot(4,4,4)
sns.violinplot(x='Result',y='on_mouseover',data=data)
plt.subplot(4,4,5)
sns.violinplot(x='Result',y='RightClick',data=data)
plt.subplot(4,4,6)
sns.violinplot(x='Result',y='popUpWidnow',data=data)
plt.subplot(4,4,7)
sns.violinplot(x='Result',y='Iframe',data=data)
plt.subplot(4,4,8)
sns.violinplot(x='Result',y='age_of_domain',data=data)
plt.subplot(4,5,1)
sns.violinplot(x='Result',y='DNSRecord',data=data)
plt.subplot(4,5,2)
sns.violinplot(x='Result',y='web_traffic',data=data)
plt.subplot(4,5,3)
sns.violinplot(x='Result',y='Page_Rank',data=data)
plt.subplot(4,5,4)
sns.violinplot(x='Result',y='Google_Index',data=data)
plt.subplot(4,5,5)
sns.violinplot(x='Result',y='Links_pointing_to_page',data=data)
plt.subplot(4,5,6)
sns.violinplot(x='Result',y='Statistical_report',data=data)
plt.show()

# %% [markdown]
# ### Heatmap Plot using Seaborn

# %%
# Get correlations of each features in dataset
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))
# Plot Heat map
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")
plt.show()

# %% [markdown]
# ### Feature Importance function to classify important Features

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(x,y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=x.columns)
feat_importances.nlargest(30).plot(kind='barh',figsize=(10,11))
plt.show()
# Out:
# C:\Users\Gagan\AppData\Roaming\Python\Python35\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# [0.01323436 0.01044068 0.0059627  0.00568363 0.003442   0.03869686
#  0.06206563 0.31456678 0.0145685  0.00426691 0.00245856 0.00726578
#  0.02599252 0.23373079 0.03886833 0.02053861 0.00517177 0.00511476
#  0.00590263 0.00410926 0.00156524 0.00503281 0.00248334 0.02021689
#  0.01231026 0.08754499 0.01161508 0.01376965 0.0187716  0.00460908]

# %% [markdown]
# # Training and Testing Part

# %% [markdown]
# ### Splitting Training and Testing DataSet

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x,y,test_size=0.30) # Splitting Train and Test DataFrame in ratio 7:3
# Train= 70%
# Test= 30%

# %% [markdown]
# ### Using Scikit-Learn

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics

# %% [markdown]
# # Logistic Regression

# %%
model= LogisticRegression()
model.fit(x_train,y_train)
# Out:
# C:\Users\Gagan\AppData\Roaming\Python\Python35\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lrpred= model.predict(x_test)
print(lrpred)

lrscore= model.score(x_test,y_test)
print(lrscore)
# Out:
# [ 1 -1 -1 ... -1 -1  1]
# 0.9258365993367501

# %%
lrcm= metrics.confusion_matrix(y_test,lrpred)
print(lrcm)
# Out:
# [[1313  143]
#  [ 103 1758]]

# %%
sns.heatmap(lrcm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'YlGnBu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(lrscore*100)
plt.title(all_sample_title, size = 15)
plt.show()

# %% [markdown]
# # Random Forest

# %%
model2 = RandomForestClassifier(n_estimators=30)
model2.fit(x,y)
rfpred=model2.predict(x)
print(rfpred)
# Out:
# [-1 -1 -1 ... -1 -1 -1]

# %%
rfscore= model2.score( x, y)
print(rfscore)
# Out:
# 0.9895974672094076

# %%
rfcm= metrics.confusion_matrix(y,rfpred)
print(rfcm)
sns.heatmap(rfcm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'YlGnBu');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(rfscore*100)
plt.title(all_sample_title, size = 15)
plt.show()
# Out:
# [[4827   71]
#  [  44 6113]]

# %% [markdown]
# # GUI

# %% [markdown]
# ### Using Tkinter

# %%
#fun function is attached to 'Show Result' button
#It Will Show The Result in PHISH WEBSITE or LEGITIMATE WEBSITE

def fun():
    lis1=[]
    lis1.append(entry1)
    lis1.append(entry2)
    lis1.append(entry3)
    lis1.append(entry4)
    lis1.append(entry5)
    lis1.append(entry6)
    lis1.append(entry7)
    lis1.append(entry8)
    lis1.append(entry9)
    lis1.append(entry10)
    lis1.append(entry11)
    lis1.append(entry12)
    lis1.append(entry13)
    lis1.append(entry14)
    lis1.append(entry15)
    lis1.append(entry16)
    lis1.append(entry17)
    lis1.append(entry18)
    lis1.append(entry19)
    lis1.append(entry20)
    lis1.append(entry21)
    lis1.append(entry22)
    lis1.append(entry23)
    lis1.append(entry24)
    lis1.append(entry25)
    lis1.append(entry26)
    lis1.append(entry27)
    lis1.append(entry28)
    lis1.append(entry29)
    lis1.append(entry30)
    liss1= np.asarray(lis1)
    
    ind=['having_IP_Address','URL_Length','Shortining_Service','having_At_Symbol','double_slash_redirecting','Prefix_Suffix',
         'having_Sub_Domain','SSLfinal_State','Domain_registeration_length','Favicon','port','HTTPS_token','Request_URL',
         'URL_of_Anchor','Links_in_tags','SFH','Submitting_to_email','Abnormal_URL','Redirect','on_mouseover','RightClick',
         'popUpWidnow','Iframe','age_of_domain','DNSRecord','web_traffic','Page_Rank','Google_Index','Links_pointing_to_page',
         'Statistical_report']
   # test_x1=pd.DataFrame(lis1,index=ind)
    
    model2 = RandomForestClassifier(n_estimators=30)
    model2.fit(x,y)
    prediction=model2.predict(liss1.T)
    print(prediction)
    if prediction==1:
        lab=Label(f1,text="RESULT= LEGITIMATE WEBSITE",font = ('arial', 14, 'bold'),bd = 14, anchor = "w",bg='lawn green')
    else:
        lab=Label(f1,text="RESULT= PHISHED WEBSITE",font = ('arial', 14, 'bold'),bd = 14, anchor = "w",bg='red')
    lab.grid(sticky= S, columnspan= 4)


    
#Reset Function will reset the entry widgets
#It is submenu in 'File' Menu
def reset():
    entry1.set("")
    entry2.set("")
    entry3.set("")
    entry4.set("")
    entry5.set("")
    entry6.set("")
    entry7.set("")
    entry8.set("")
    entry9.set("")
    entry10.set("")
    entry11.set("")
    entry12.set("")
    entry13.set("")
    entry14.set("")
    entry15.set("")
    entry16.set("")
    entry17.set("")
    entry18.set("")
    entry19.set("")
    entry20.set("")
    entry21.set("")
    entry22.set("")
    entry23.set("")
    entry24.set("")
    entry25.set("")
    entry26.set("")
    entry27.set("")
    entry28.set("")
    entry29.set("")
    entry30.set("")
    lab=Label(f1,text="                                       ",font = ('arial', 14, 'bold'),bd = 14, anchor = "w")
    lab.grid(sticky= S, columnspan= 4)

# %%
from tkinter import *

win= Tk()

label0= Label(win, text= "DETECTION OF PHISHING WEBSITE")
label0.grid(sticky= N, columnspan= 4)

label1=  Label(win, text= "having_IP_Address")
label2=  Label(win, text= "URL_Length")
label3=  Label(win, text= "Shortining_Service")
label4=  Label(win, text= "having_At_Symbol")
label5=  Label(win, text= "double_slash_redirecting")
label6=  Label(win, text= "Prefix_Suffix")
label7=  Label(win, text= "having_Sub_Domain")
label8=  Label(win, text= "SSLfinal_State")
label9=  Label(win, text= "Domain_registeration_length")
label10= Label(win, text= "Favicon")
label11= Label(win, text= "port")
label12= Label(win, text= "HTTPS_token")
label13= Label(win, text= "Request_URL")
label14= Label(win, text= "URL_of_Anchor")
label15= Label(win, text= "Links_in_tags")
label16= Label(win, text= "SFH")
label17= Label(win, text= "Submitting_to_email")
label18= Label(win, text= "Abnormal_URL")
label19= Label(win, text= "Redirect")
label20= Label(win, text= "on_mouseover")
label21= Label(win, text= "RightClick")
label22= Label(win, text= "popUpWidnow")
label23= Label(win, text= "Iframe")
label24= Label(win, text= "age_of_domain")
label25= Label(win, text= "DNSRecord")
label26= Label(win, text= "web_traffic")
label27= Label(win, text= "Page_Rank")
label28= Label(win, text= "Google_Index")
label29= Label(win, text= "Links_pointing_to_page")
label30= Label(win, text= "Statistical_report")

# %%
entry1 = Entry(win)
entry1.grid(row=15, column=1)
entry2 = Entry(win)
entry2.grid(row=1, column=1)
entry3 = Entry(win)
entry3.grid(row=2, column=1)
entry4 = Entry(win)
entry4.grid(row=3, column=1)
entry5 = Entry(win)
entry5.grid(row=4, column=1)
entry6 = Entry(win)
entry6.grid(row=5, column=1)
entry7 = Entry(win)
entry7.grid(row=6, column=1)
entry8 = Entry(win)
entry8.grid(row=7, column=1)
entry9 = Entry(win)
entry9.grid(row=8, column=1)
entry10 = Entry(win)
entry10.grid(row=9, column=1)
entry11 = Entry(win)
entry11.grid(row=10, column=1)
entry12 = Entry(win)
entry12.grid(row=11, column=1)
entry13 = Entry(win)
entry13.grid(row=12, column=1)
entry14 = Entry(win)
entry14.grid(row=13, column=1)
entry15 = Entry(win)
entry15.grid(row=14, column=1)
entry16 = Entry(win)
entry16.grid(row=15, column=3)
entry17 = Entry(win)
entry17.grid(row=1, column=3)
entry18 = Entry(win)
entry18.grid(row=2, column=3)
entry19 = Entry(win)
entry19.grid(row=3, column=3)
entry20 = Entry(win)
entry20.grid(row=4, column=3)
entry21 = Entry(win)
entry21.grid(row=5, column=3)
entry22 = Entry(win)
entry22.grid(row=6, column=3)
entry23 = Entry(win)
entry23.grid(row=7, column=3)
entry24 = Entry(win)
entry24.grid(row=8, column=3)
entry25 = Entry(win)
entry25.grid(row=9, column=3)
entry26 = Entry(win)
entry26.grid(row=10, column=3)
entry27 = Entry(win)
entry27.grid(row=11, column=3)
entry28 = Entry(win)
entry28.grid(row=12, column=3)
entry29 = Entry(win)
entry29.grid(row=13, column=3)
entry30 = Entry(win)
entry30.grid(row=14, column=3)

# %%
# Buttons part

predict_button= Button(win, text= "Prediction", command= fun, fg= "blue")
predict_button.grid(row=18, column=0, columnspan=2)

reset_button= Button(win, text= "Reset", command= reset, fg= "red")
reset_button.grid(row=18, column=2, columnspan=2)

# %%
label1.grid(row=15,column=0)
label2.grid(row=1,column=0)
label3.grid(row=2,column=0)
label4.grid(row=3,column=0)
label5.grid(row=4,column=0)
label6.grid(row=5,column=0)
label7.grid(row=6,column=0)
label8.grid(row=7,column=0)
label9.grid(row=8,column=0)
label10.grid(row=9,column=0)
label11.grid(row=10,column=0)
label12.grid(row=11,column=0)
label13.grid(row=12,column=0)
label14.grid(row=13,column=0)
label15.grid(row=14,column=0)

label16.grid(row=15,column=2)
label17.grid(row=1,column=2)
label18.grid(row=2,column=2)
label19.grid(row=3,column=2)
label20.grid(row=4,column=2)
label21.grid(row=5,column=2)
label22.grid(row=6,column=2)
label23.grid(row=7,column=2)
label24.grid(row=8,column=2)
label25.grid(row=9,column=2)
label26.grid(row=10,column=2)
label27.grid(row=11,column=2)
label28.grid(row=12,column=2)
label29.grid(row=13,column=2)
label30.grid(row=14,column=2)

# %% [markdown]
# # Running the GUI Window

# %%
win.mainloop()
